# %% [markdown]
# # Lab 6: Extracting Job Posts from Indeed

# %%
import pandas
import configparser
import psycopg2

# %%
config = configparser.ConfigParser()
config.read('config.ini')

host = config['myaws']['host']
database = config['myaws']['database']
user = config['myaws']['user']
pwd = config['myaws']['pwd']

# %%
conn = psycopg2.connect(host = host,
                       user = user,
                        password = pwd,
                        dbname = database
                       )
cur = conn.cursor()

# %%
table_sql = """
            CREATE TABLE IF NOT EXISTS indeed_gp9
            (
                id SERIAL,
                job_title VARCHAR(200),
                job_company VARCHAR(200),
                job_loc VARCHAR(200),
                job_salary VARCHAR(200),
                job_summary TEXT,
                PRIMARY KEY(id)
            );

            """

# %%
cur.execute(table_sql)
conn.commit()

# %% [markdown]
# ## Request HTML

# %%
url = 'https://www.indeed.com/jobs?q=intelligence+analyst&start=40'

# %%
import urllib.request
response = urllib.request.urlopen(url)
html_data= response.read()
#print(html_data.decode('utf-8'))

# %% [markdown]
# ## Parse HTML

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.6.0)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data,'html.parser')
#print (soup)

# %%
for table_resultsBody in soup.find_all('table', id = 'resultsBody'):
    pass
    #print(table_resultsBody)

# %%
for table_pageContent in table_resultsBody.find_all('table', id = 'pageContent'):
    pass
    #print(table_pageContent)

# %%
for td_resultsCol in table_pageContent.find_all('td', id = 'resultsCol'):
    pass
    #print(td_resultsCol)

# %%
#  identify the job title, company, ratings, reviews, salary, and summary
for div_row in td_resultsCol.find_all('div', class_='jobsearch-SerpJobCard unifiedRow row result'):

    # find job title
    job_title = None
    job_company  = None
    job_rating = None
    job_loc = None
    job_salary = None
    job_summary = None
    for div_title in div_row.find_all('div', class_ = 'title'):
        job_title = div_title.text.strip().replace("'","_")
    
    for div_dsc in div_row.find_all('div', class_ = 'sjcl'):
        
        #find company name
        for span_company in div_dsc.find_all('span', class_ = 'company'):
            job_company = span_company.text.strip().replace("'","_")
        
        # find location
        for div_loc in div_dsc.find_all('div', class_ = 'location accessible-contrast-color-location'):
            job_loc = div_loc.text.strip().replace("'","_")
    
    # find salary
    for div_salary in div_row.find_all('div',class_ ='salarySnippet'):
        job_salary = div_salary.text.strip().replace("'","_")
    
    #find summary
    for div_summary in div_row.find_all('div', class_ = 'summary'):
        job_summary = div_summary.text.strip().replace("'","_")
        
    # insert into database
    
    sql_insert = """
                insert into indeed_gp9(job_title,job_company,job_loc,job_salary,job_summary)
                values('{}','{}','{}','{}','{}')            
                """.format(job_title,job_company,job_loc,job_salary,job_summary)

    cur.execute(sql_insert)
    conn.commit()

# %% [markdown]
# ## View the Table

# %%
df = pandas.read_sql_query('select * from indeed_gp9', conn)
df[:]
# Out:
#     id                                          job_title  \
# 0    1                               Intelligence Analyst
# 1    2  Undergraduate Internship/Co-op Program - Intel...
# 2    3           H-ISAC Cyber Threat Intelligence Analyst
# 3    4                      Acoustic Intelligence Analyst
# 4    5  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 5    6                             Transportation Analyst
# 6    7                               Intelligence Analyst
# 7    8                       Intelligence Analyst I - MRS
# 8    9                               Intelligence Analyst
# 9   10                               Intelligence Analyst
# 10  11                               Intelligence Analyst
# 11  12  Global Intelligence & Travel Security Operatio...
# 12  13                               Intelligence Analyst
# 13  14                               Intelligence Analyst
# 14  15       Intelligence Analyst (Identity Intelligence)
# 15  16                               Intelligence Analyst
# 16  17                   Quantitative Analyst / Developer
# 17  18               Associate Cyber Intelligence Analyst
# 18  19                Intelligence Analyst_Washington, DC
# 19  20                              INVESTIGATIVE ANALYST
# 20  21     Information Intelligence and Reporting Analyst
# 21  22                               Intel Analyst, Assoc
# 22  23             Entry Level Accenture Security Analyst
# 23  24   Competitive Intelligence/Position-to-Win Analyst
# 24  25    Spanish or Portuguese Language Research Analyst
# 25  26                              Investigative Analyst
# 26  27                       Open Source Research Analyst
# 27  28  Law Enforcement/Criminal Intelligence/Physical...
# 28  29                         Brand Intelligence Analyst
# 29  30           H-ISAC Cyber Threat Intelligence Analyst
# 30  31                                    Vetting Analyst
# 31  32  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 32  33                      Acoustic Intelligence Analyst
# 33  34  Undergraduate Internship/Co-op Program - Intel...
# 34  35               Associate Cyber Intelligence Analyst
# 35  36                               Intelligence Analyst
# 36  37                Intelligence Analyst_Washington, DC
# 37  38     Information Intelligence and Reporting Analyst
# 38  39                 Intelligence Operations Specialist
# 39  40                               Intelligence Analyst
# 40  41                               Intel Analyst, Assoc
# 41  42  Law Enforcement/Criminal Intelligence/Physical...
# 42  43             Entry Level Accenture Security Analyst
# 43  44                              Investigative Analyst
# 44  45              Intelligence Specialist (GMI Analyst)
# 45  46  Open Source Intelligence Analyst Intern (Summe...
# 46  47                   Quantitative Analyst / Developer
# 47  48                ERP Applications Developer (Epicor)
# 48  49                      Acoustic Intelligence Analyst
# 49  50           H-ISAC Cyber Threat Intelligence Analyst
# 50  51                         Brand Intelligence Analyst
# 51  52  Cybersecurity Analyst (DLP) (60-70k, US Citize...
# 52  53  Undergraduate Internship/Co-op Program - Intel...
# 53  54               Associate Cyber Intelligence Analyst
# 54  55                               Intelligence Analyst
#
#                           job_company                            job_loc  \
# 0            National Security Agency                     Fort Meade, MD
# 1         Central Intelligence Agency                     Washington, DC
# 2                      Perch Security                     Titusville, FL
# 3                           Perspecta                 Suitland, MD 20746
# 4                             Maveris                    Martinsburg, WV
# 5                 Lipman Family Farms                Immokalee, FL 34142
# 6                 Booz Allen Hamilton                               None
# 7                          WorldAware                               None
# 8                         BAE Systems                               None
# 9               5 Stones intelligence                               None
# 10           National Security Agency                               None
# 11                          Pinkerton                               None
# 12             Red Five Security, LLC                               None
# 13                             Splunk                               None
# 14             Signature Science, LLC                               None
# 15                IntelliWare Systems                               None
# 16                          RT Signal  New York, NY 10013 (Tribeca area)
# 17       LookingGlass Cyber Solutions                   Reston, VA 20191
# 18           Sawdey Solution Services                               None
# 19          US Department of the Navy                               None
# 20                           Allstate                               None
# 21                   KEYW Corporation                               None
# 22                          Accenture                               None
# 23        LOCKHEED MARTIN CORPORATION                               None
# 24  Integrity Risk International, LLC                               None
# 25                          Pinkerton                               None
# 26           US Department of Defense                               None
# 27            Sancorp Consulting, LLC                               None
# 28       LookingGlass Cyber Solutions                   Reston, VA 20191
# 29                     Perch Security                     Titusville, FL
# 30  ManTech International Corporation               Colorado Springs, CO
# 31                            Maveris                    Martinsburg, WV
# 32                          Perspecta                 Suitland, MD 20746
# 33        Central Intelligence Agency                     Washington, DC
# 34       LookingGlass Cyber Solutions                   Reston, VA 20191
# 35           National Security Agency                     Fort Meade, MD
# 36           Sawdey Solution Services                               None
# 37                           Allstate                               None
# 38           US Department of Defense                               None
# 39            Halfaker and Associates                               None
# 40                   KEYW Corporation                               None
# 41            Sancorp Consulting, LLC                               None
# 42                          Accenture                               None
# 43                          Pinkerton                               None
# 44          US Department of the Army                               None
# 45                        CrowdStrike                               None
# 46                          RT Signal  New York, NY 10013 (Tribeca area)
# 47               Ashworth Bros., Inc.               Winchester, VA 22601
# 48                          Perspecta                 Suitland, MD 20746
# 49                     Perch Security                     Titusville, FL
# 50       LookingGlass Cyber Solutions                   Reston, VA 20191
# 51                            Maveris                    Martinsburg, WV
# 52        Central Intelligence Agency                     Washington, DC
# 53       LookingGlass Cyber Solutions                   Reston, VA 20191
# 54           National Security Agency                     Fort Meade, MD
#
#                    job_salary  \
# 0   $69,581 - $108,422 a year
# 1     $21.21 - $22.43 an hour
# 2    $50,000 - $75,000 a year
# 3                        None
# 4    $60,000 - $70,000 a year
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
# 10   $47,016 - $74,759 a year
# 11                       None
# 12                       None
# 13                       None
# 14                       None
# 15                       None
# 16  $95,000 - $165,000 a year
# 17                       None
# 18                       None
# 19                       None
# 20                       None
# 21                       None
# 22                       None
# 23                       None
# 24                       None
# 25                       None
# 26                       None
# 27                       None
# 28                       None
# 29                       None
# 30                       None
# 31                       None
# 32                       None
# 33                       None
# 34                       None
# 35                       None
# 36                       None
# 37                       None
# 38  $99,172 - $128,920 a year
# 39                       None
# 40                       None
# 41                       None
# 42                       None
# 43                       None
# 44  $88,704 - $115,313 a year
# 45                       None
# 46  $95,000 - $165,000 a year
# 47                       None
# 48                       None
# 49   $50,000 - $75,000 a year
# 50                       None
# 51   $60,000 - $70,000 a year
# 52    $21.21 - $22.43 an hour
# 53                       None
# 54   $47,016 - $74,759 a year
#
#                                           job_summary
# 0   NSA Intelligence Analysts are expected to take...
# 1   Engineering, science students, or those in oth...
# 2   Ability to communicate technical issues to tec...
# 3   We provide solutions to improve the Nation_s d...
# 4   The Analyst can identify risks in security sys...
# 5   Perform fact based, data driven analysis, and ...
# 6   We’re an EOE that empowers our people—no matte...
# 7   WorldAware is dedicated to equal opportunity i...
# 8   Having an understanding of physical and techni...
# 9   Analyze threat information from multiple sourc...
# 10  The National Security Agency (NSA) is part of ...
# 11  The Global Intelligence & Travel Security Oper...
# 12  We do not discriminate on the basis of race, r...
# 13  All qualified applicants will receive consider...
# 14  The purpose of this position is to provide tec...
# 15  The analyst will provide terrorist related thr...
# 16  We are a small, but well-funded (financially s...
# 17  Past experience in intelligence, technology, c...
# 18  Sawdey Solution Services, Inc., an ISO 9001 ce...
# 19  Within the Department of Defense (DoD), the ap...
# 20  Therefore, any discriminatory action taken on ...
# 21  (1) race, (2) religion, (3) creed, (4) color, ...
# 22  Combining unmatched experience and specialized...
# 23  All qualified applicants will receive consider...
# 24  Research Analysts use a wide array of database...
# 25  The Analyst will complete all-source research,...
# 26  All candidates will be considered without rega...
# 27  Must demonstrate the ability to apply systemat...
# 28  The Brand Intelligence Analyst employs our pro...
# 29  Ability to communicate technical issues to tec...
# 30  We do not discriminate against any employee or...
# 31  The Analyst can identify risks in security sys...
# 32  We provide solutions to improve the Nation_s d...
# 33  Engineering, science students, or those in oth...
# 34  Past experience in intelligence, technology, c...
# 35  The National Security Agency (NSA) is part of ...
# 36  Sawdey Solution Services, Inc., an ISO 9001 ce...
# 37  Therefore, any discriminatory action taken on ...
# 38  It must include your name and contact informat...
# 39  We are proud to be an Equal Opportunity/Affirm...
# 40  (1) race, (2) religion, (3) creed, (4) color, ...
# 41  Must demonstrate the ability to apply systemat...
# 42  Combining unmatched experience and specialized...
# 43  The Analyst will complete all-source research,...
# 44  Specialized experience is defined as experienc...
# 45  All qualified applicants will receive consider...
# 46  We are a small, but well-funded (financially s...
# 47  This may include custom mobile and windows app...
# 48  We provide solutions to improve the Nation_s d...
# 49  Ability to communicate technical issues to tec...
# 50  The Brand Intelligence Analyst employs our pro...
# 51  The Analyst can identify risks in security sys...
# 52  Engineering, science students, or those in oth...
# 53  Past experience in intelligence, technology, c...
# 54  The National Security Agency (NSA) is part of ...

# %%
cur.close()
conn.close()
